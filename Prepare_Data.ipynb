# %%
import os
import glob
import shutil
import random
from tqdm import tqdm

# %%
raw_data = 'C:/Users/lourd/Documents/Lulu/Cursos 2021/Master Data Science/22 Trabajo Fin de Master/Competicion Becas/Data/mrlEyes_2018_01'
for dirpath, dirname, filename in os.walk(raw_data):
    for file in tqdm([f for f in filename if f.endswith('.png')]):
        if file.split('_')[4] == '0':
            path='C:/Users/lourd/Documents/Lulu/Cursos 2021/Master Data Science/22 Trabajo Fin de Master/Competicion Becas/Data/train/closed'
            if not os.path.exists(path):
                os.makedirs(path)
            shutil.copy(src=dirpath + '/' + file, dst= path)
        elif file.split('_')[4] == '1':
            path='C:/Users/lourd/Documents/Lulu/Cursos 2021/Master Data Science/22 Trabajo Fin de Master/Competicion Becas/Data/train/open'
            if not os.path.exists(path):
                os.makedirs(path)
            shutil.copy(src=dirpath + '/' + file, dst= path)
# Out:
# 0it [00:00, ?it/s]
# 100%|██████████| 3242/3242 [00:09<00:00, 342.20it/s]
# 100%|██████████| 1114/1114 [00:04<00:00, 267.40it/s]
# 100%|██████████| 679/679 [00:02<00:00, 264.08it/s]
# 100%|██████████| 1069/1069 [00:02<00:00, 357.64it/s]
# 100%|██████████| 736/736 [00:02<00:00, 334.39it/s]
# 100%|██████████| 1012/1012 [00:03<00:00, 329.48it/s]
# 100%|██████████| 624/624 [00:01<00:00, 399.06it/s]
# 100%|██████████| 832/832 [00:02<00:00, 387.31it/s]
# 100%|██████████| 387/387 [00:01<00:00, 366.54it/s]
# 100%|██████████| 399/399 [00:01<00:00, 334.04it/s]
# 100%|██████████| 1648/1648 [00:07<00:00, 214.32it/s]
# 100%|██████████| 8728/8728 [00:25<00:00, 341.38it/s]
# 100%|██████████| 3605/3605 [00:09<00:00, 378.34it/s]
# 100%|██████████| 8884/8884 [00:24<00:00, 359.62it/s]
# 100%|██████████| 1132/1132 [00:03<00:00, 366.82it/s]
# 100%|██████████| 1889/1889 [00:04<00:00, 388.97it/s]
# 100%|██████████| 1648/1648 [00:05<00:00, 281.10it/s]
# 100%|██████████| 4410/4410 [00:12<00:00, 356.73it/s]
# 100%|██████████| 6175/6175 [00:16<00:00, 372.50it/s]
# 100%|██████████| 704/704 [00:02<00:00, 345.96it/s]
# 100%|██████████| 987/987 [00:03<00:00, 302.62it/s]
# 100%|██████████| 382/382 [00:00<00:00, 402.69it/s]
# 100%|██████████| 522/522 [00:01<00:00, 419.48it/s]
# 100%|██████████| 752/752 [00:01<00:00, 429.49it/s]
# 100%|██████████| 1502/1502 [00:03<00:00, 390.77it/s]
# 100%|██████████| 1246/1246 [00:03<00:00, 341.60it/s]
# 100%|██████████| 665/665 [00:01<00:00, 391.76it/s]
# 100%|██████████| 736/736 [00:01<00:00, 373.91it/s]
# 100%|██████████| 1393/1393 [00:03<00:00, 373.04it/s]
# 100%|██████████| 1384/1384 [00:03<00:00, 390.72it/s]
# 100%|██████████| 1738/1738 [00:04<00:00, 349.51it/s]
# 100%|██████████| 6162/6162 [00:19<00:00, 311.25it/s]
# 100%|██████████| 681/681 [00:01<00:00, 365.51it/s]
# 100%|██████████| 739/739 [00:01<00:00, 387.68it/s]
# 100%|██████████| 642/642 [00:01<00:00, 405.60it/s]
# 100%|██████████| 6193/6193 [00:16<00:00, 368.20it/s]
# 100%|██████████| 10257/10257 [00:39<00:00, 260.72it/s]

# %%
def create_test_closed(source, destination, percent):
    '''
    divides closed eyes images into given percent and moves from
    source to destination.
    
    Arguments:
    source(path): path of source directory
    destination(path): path of destination directory
    percent(float): percent of data to be divided(range: 0 to 1)
    '''
    path, dirs, files_closed = next(os.walk(source))
    file_count_closed = len(files_closed)
    percentage = file_count_closed * percent
    to_move = random.sample(glob.glob(source + "/*.png"), int(percentage))

    for f in enumerate(to_move):
        if not os.path.exists(destination):
            os.makedirs(destination)
        shutil.move(f[1], destination)
    print(f'moved {int(percentage)} images to the destination successfully.')

# %%
def create_test_open(source, destination, percent):
    '''
    divides open eyes images into given percent and moves from
    source to destination.
    
    Arguments:
    source(path): path of source directory
    destination(path): path of destination directory
    percent(float): percent of data to be divided(range: 0 to 1)
    '''
    path, dirs, files_open = next(os.walk(source))
    file_count_open = len(files_open)
    percentage = file_count_open * percent
    to_move = random.sample(glob.glob(source + "/*.png"), int(percentage))

    for f in enumerate(to_move):
        if not os.path.exists(destination):
            os.makedirs(destination)
        shutil.move(f[1], destination)
    print(f'moved {int(percentage)} images to the destination successfully.')

# %%
create_test_closed('C:/Users/lourd/Documents/Lulu/Cursos 2021/Master Data Science/22 Trabajo Fin de Master/Competicion Becas/Data/train/closed', 
                    'C:/Users/lourd/Documents/Lulu/Cursos 2021/Master Data Science/22 Trabajo Fin de Master/Competicion Becas/Data/test/closed', 
                    0.2)
# Out:
# moved 8389 images to the destination successfully.

# %%
create_test_open('C:/Users/lourd/Documents/Lulu/Cursos 2021/Master Data Science/22 Trabajo Fin de Master/Competicion Becas/Data/train/open', 
                    'C:/Users/lourd/Documents/Lulu/Cursos 2021/Master Data Science/22 Trabajo Fin de Master/Competicion Becas/Data/test/open', 
                    0.2)
# Out:
# moved 8590 images to the destination successfully.
